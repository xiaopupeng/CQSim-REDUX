# %%
### for MacOS or Linux ###
# check whats in the root folder
from subprocess import check_output
print(check_output(['ls', './']).decode('utf8'))

# %% [markdown]
# # Imports

# %%
import sys
### for Mac
# sys.path.insert(0, '/Users/xiaopupeng/dropbox/workspace/cqsim-redux/')
### for PC
sys.path.insert(0, 'C:/Users/xzp0007/Dropbox/Workspace/CQSim-REDUX/')
import os
import copy
from datetime import datetime
import time
import re
import random
import numpy as np
import pandas as pd
# %matplotlib inline
# %matplotlib notebook
# %matplotlib widget
import matplotlib
import matplotlib.pyplot as plt
import itertools
# import Redux as rd
plt.style.use('ggplot')
# plt.style.use('default')

# %%
### For Mac
# path_main='/Users/xiaopupeng/dropbox/workspace/cqsim-redux/'
### for PC
path_main='C:/Users/xzp0007/Dropbox/Workspace/CQSim-REDUX/'
path_data=path_main+'data/'
redux_src=path_main+'srcREDUX/'
cqsim_src=path_main+'srcCQSim/'
sys.path.append(path_main)

# %%
### CQSim modules ###
# preprocess
import srcCQSim.Filter.Filter_job_SWF as FilterJob
import srcCQSim.CqSim.Job_trace as JobTrace
import srcCQSim.Filter.Filter_node_SWF as FilterNode
import srcCQSim.CqSim.Node_struc as NodeStruc
# algorithms
import srcCQSim.CqSim.Start_window as StartWindow
# record the results
import srcCQSim.CqSim.Info_collect as InfoCollect
# import srcCQSim.Output_log as OutputLog

# new module of renewable energy aware
import srcCQSim.CqSim.power as Power
# simulator
import srcCQSim.ReCqsim_sim as CqsimSim

### REDUX modules ###
import srcREDUX.REDUX.DataIO as dataIO
import srcREDUX.REDUX.Update as update
import srcREDUX.REDUX.Predict_Smooth as predict_smooth
import srcREDUX.REDUX.Results as results
import srcREDUX.ReduxSim as ReduxSim

# %%
#ReCq module
import ReCqSim
#main method
import cqsim_redux as cr

# %% [markdown]
# # Initialize

# %%
# assign default value to all parameters
def initCQ():
    inputCQ = {
    ### job trace name and save file names ###
    # 'job_trace': 'test2.swf',
    # 'job_save': 'jobSave_test2',
#     'job_trace': 'SDSC-SP2-1998-4.2-cln.swf',
#     'job_trace': 'SDSC-BLUE-2000-4.2-cln.swf',
    'job_trace': 'Sandia-Ross-2001-1.1-cln.swf',
#     'job_trace': 'LLNL-Atlas-2006-2.1-cln.swf',
#     'job_trace': 'UniLu-Gaia-2014-1.swf',
    'job_save': 'jobSave_SDSC-SP2-1998-4.2-cln',
    ### system config ###
    'cluster_fraction': 1.0,
    'start': 0.0,
    'start_date': 'None',
    'anchor': 0,
    'read_num': 18000,
    ### algorithm config ###
    # w:job wait time s: submit time t: requested time n: requested processors q:priority queue
    'win': 1, # =1 for window_check mode, other for no check
    'win_para': ['5', '0', '0'],
    #start window module parameter: [window size],[check size],[max start size],[max window size]
    ### config of names ###
    'config': 'config.set',
    'pre_name': "CQSIM_",
    'path_in': path_data+'InputCQSim/',
    'path_fmt': path_data+'Fmt/',
    #### 0:Read original file  1:Read formatted file ###
    'resource_job': 0,
    'resource_node': 0
    }
    return inputCQ

def initRE():
    inputRE = {
    # ### CONSTANT ###
    # ratio of stats count when start the arithmetic average estimate
    'scaleRatio': 0.01,
    # ability of ups devise, could be more sophisticated in future (kWh)
    'upsCapability': 500,
    # the workload processing capability of data center (in processors)
    # 'dataCenterCap': 2500,
    'nodNum': 1152,
    'procPerNode': 8,
    # ups and renewable energy price ($)
    'upsPrice': 0.02,
    'solarPrice': 0.09,
    'windPrice': 0.15,
    # ### INITIALIZE ###
    # the initialized threshold of grid price ($)
    'initGridpriceThreshold': 1.0,
    # initialized high and low ratio of current workload for workload shaving
    'initCurWorkloadRatio': 0.2,
    # initialized stable renewable supply level
    'initStableRenSupply': 500,
    ### config of names ###
    'path_in': path_data+'InputREDUX/',
    'path_out': path_data+'REDUXResults/',
    }
    return inputRE

inputCQ=initCQ()
inputRE=initRE()

# %%
cr.showInputAndSetName(inputCQ, inputRE)
trace_name = inputCQ['path_in'] + inputCQ['job_trace']
save_name_j = inputCQ['path_fmt'] + inputCQ['job_save'] + '.csv'
config_name_j = inputCQ['path_fmt'] + inputCQ['job_save'] + '.txt'
# Out:
# ....................
# job_trace: Sandia-Ross-2001-1.1-cln.swf
# job_save: jobSave_SDSC-SP2-1998-4.2-cln
# cluster_fraction: 1.0
# start: 0.0
# start_date: None
# anchor: 0
# read_num: 18000
# win: 1
# win_para: ['5', '0', '0']
# config: config.set
# pre_name: CQSIM_
# path_in: C:/Users/xzp0007/Dropbox/Workspace/CQSim-REDUX/data/InputCQSim/
# path_fmt: C:/Users/xzp0007/Dropbox/Workspace/CQSim-REDUX/data/Fmt/
# resource_job: 0
# resource_node: 0
# ....................
# scaleRatio: 0.01
# upsCapability: 500
# nodNum: 1152
# procPerNode: 8
# upsPrice: 0.02
# solarPrice: 0.09
# windPrice: 0.15
# initGridpriceThreshold: 1.0
# initCurWorkloadRatio: 0.2
# initStableRenSupply: 500
# path_in: C:/Users/xzp0007/Dropbox/Workspace/CQSim-REDUX/data/InputREDUX/
# path_out: C:/Users/xzp0007/Dropbox/Workspace/CQSim-REDUX/data/REDUXResults/
# ....................

# %%
# %whos
# Out:
# Variable         Type        Data/Info
# --------------------------------------
# CqsimSim         module      <module 'srcCQSim.ReCqsim<...>rcCQSim\\ReCqsim_sim.py'>
# FilterJob        module      <module 'srcCQSim.Filter.<...>lter\\Filter_job_SWF.py'>
# FilterNode       module      <module 'srcCQSim.Filter.<...>ter\\Filter_node_SWF.py'>
# InfoCollect      module      <module 'srcCQSim.CqSim.I<...>\CqSim\\Info_collect.py'>
# JobTrace         module      <module 'srcCQSim.CqSim.J<...>im\\CqSim\\Job_trace.py'>
# NodeStruc        module      <module 'srcCQSim.CqSim.N<...>m\\CqSim\\Node_struc.py'>
# Power            module      <module 'srcCQSim.CqSim.p<...>cCQSim\\CqSim\\power.py'>
# ReCqSim          module      <module 'ReCqSim' from 'C<...>CQSim-REDUX\\ReCqSim.py'>
# ReduxSim         module      <module 'srcREDUX.ReduxSi<...>\\srcREDUX\\ReduxSim.py'>
# StartWindow      module      <module 'srcCQSim.CqSim.S<...>\CqSim\\Start_window.py'>
# config_name_j    str         C:/Users/xzp0007/Dropbox/<...>SDSC-SP2-1998-4.2-cln.txt
# copy             module      <module 'copy' from 'C:\\<...>Anaconda3\\lib\\copy.py'>
# cqsim_src        str         C:/Users/xzp0007/Dropbox/<...>ace/CQSim-REDUX/srcCQSim/
# cr               module      <module 'cqsim_redux' fro<...>m-REDUX\\cqsim_redux.py'>
# dataIO           module      <module 'srcREDUX.REDUX.D<...>REDUX\\REDUX\\DataIO.py'>
# datetime         type        <class 'datetime.datetime'>
# initCQ           function    <function initCQ at 0x0000025BBDC3B430>
# initRE           function    <function initRE at 0x0000025BBDC3B4C0>
# inputCQ          dict        n=15
# inputRE          dict        n=12
# itertools        module      <module 'itertools' (built-in)>
# np               module      <module 'numpy' from 'C:\<...>ges\\numpy\\__init__.py'>
# os               module      <module 'os' from 'C:\\Us<...>\\Anaconda3\\lib\\os.py'>
# path_data        str         C:/Users/xzp0007/Dropbox/<...>rkspace/CQSim-REDUX/data/
# path_main        str         C:/Users/xzp0007/Dropbox/Workspace/CQSim-REDUX/
# pd               module      <module 'pandas' from 'C:<...>es\\pandas\\__init__.py'>
# plt              module      <module 'matplotlib.pyplo<...>\\matplotlib\\pyplot.py'>
# predict_smooth   module      <module 'srcREDUX.REDUX.P<...>EDUX\\Predict_Smooth.py'>
# random           module      <module 'random' from 'C:<...>aconda3\\lib\\random.py'>
# re               module      <module 're' from 'C:\\Us<...>\\Anaconda3\\lib\\re.py'>
# redux_src        str         C:/Users/xzp0007/Dropbox/<...>ace/CQSim-REDUX/srcREDUX/
# results          module      <module 'srcREDUX.REDUX.R<...>EDUX\\REDUX\\Results.py'>
# save_name_j      str         C:/Users/xzp0007/Dropbox/<...>SDSC-SP2-1998-4.2-cln.csv
# sys              module      <module 'sys' (built-in)>
# time             module      <module 'time' (built-in)>
# trace_name       str         C:/Users/xzp0007/Dropbox/<...>LPC-EGEE-2004-1.2-cln.swf
# update           module      <module 'srcREDUX.REDUX.U<...>REDUX\\REDUX\\Update.py'>

# %% [markdown]
# # Module Stucture & Init

# %%
### CQSim modules ###
print( ".................... Job Filter" )
module_filter_job = FilterJob.Filter_job_SWF(trace=trace_name, save=save_name_j, config=config_name_j)
module_filter_job.read_job_trace()
module_filter_job.output_job_data()
module_filter_job.output_job_config()

print( ".................... Job Trace" )
module_job_trace = JobTrace.Job_trace(start=inputCQ['start'],num=inputCQ['read_num'],anchor=inputCQ['anchor'],density=inputCQ['cluster_fraction'])
module_job_trace.import_job_file(save_name_j)
module_job_trace.import_job_config(config_name_j)

print("................ Power Profile")
module_pow = Power.Power(job_module=module_job_trace)
# power profile input: 1.processors 2.runtime
# power supply input:

print( ".................... Start Window" )
module_win = StartWindow.Start_window(mode=inputCQ['win'],power_module=module_pow,para_list=inputCQ['win_para'])

print( ".................... Information Collect" )
module_info_collect = InfoCollect.Info_collect()

# # Output Log
# print( ".................... Output Log" )
# module_output_log = OutputLog.Output_log (output=output_fn)

### REDUX modules ###
print(".................... Data Input")
input_module = dataIO.DataIO(inputPara = inputRE)
input_module.loadData()
inputRE['dataSize'] = input_module.data_size
print('data size:', inputRE['dataSize'])

print(".................... Update")
update_module = update.Update(inputPara=inputRE)

print(".................... Predict&Smooth")
predict_smooth_module = predict_smooth.Predict_Smooth(inputRE, update_module)

print(".................... Smooth")
results_module = results.Results()

# print(".................... Print Output")
# output_module = dataIO.DataIO(inputRE)

# Cqsim Simulator
print( ".................... Cqsim Simulator" )
module_list_cq = {
'job':module_job_trace,
'win':module_win,
'pow':module_pow,
'info':module_info_collect
# 'output':module_output_log
}
module_CQsim = CqsimSim.Cqsim_sim(module_list=module_list_cq)
module_list_cq['CQsim']=module_CQsim

# REDUX Simulator
print(".................... Redux Simulator")
module_list_re = {
'input':input_module,
'update': update_module,
'predsmoo': predict_smooth_module,
'results': results_module
# 'output':output_module
}
module_REsim = ReduxSim.Redux_Sim(module_list=module_list_re)
module_list_re['REsim']=module_REsim
# Out:
# .................... Job Filter
# .................... Job Trace
# {'date': 'Thu Nov 29 12:11:26 MST 2001', 'start_offset': '0.0'}
# ................ Power Profile
# .................... Start Window
# .................... Information Collect
# .................... Data Input
# data size: 2568
# .................... Update
# .................... Predict&Smooth
# .................... Smooth
# .................... Cqsim Simulator
# Job Trace ................... Load
# Start Window ................... Load
# Power ................... Load
# Info Collect ................... Load
# .................... Redux Simulator
# DataIO ................... Load
# Update ................... Load
# Predict_Smooth ................... Load
# Results ................... Load

# %% [markdown]
# # StartSim

# %% [markdown]
# ## ren-aware

# %%
# Init Integraded Simulator
module_sim = ReCqSim.ReCqSim(module_list_cq=module_list_cq, module_list_re=module_list_re)
# Out:
# >>>>>>>>>>>>>> ReCqSim modules list:
# Job Trace ................... Load
# Start Window ................... Load
# Power ................... Load
# Info Collect ................... Load
# Cqsim Sim ................... Load
# DataIO ................... Load
# Update ................... Load
# Predict_Smooth ................... Load
# Results ................... Load
# ReduxSim ................... Load

# %%
print('======================','ren-aware Sim','======================')
curHour = 0
dataSize = module_sim.REmod['input'].get_data_size()
print('data size >>>>>>>>>>>>>>>>>>>>', dataSize)
dataCenterCap = module_sim.REmod['update'].data_center_cap() // 40
print('data center Capabiliy >>>>>>>>>>>>>>>>>>>>', dataCenterCap)
dataCenterCapScaleRatio = 0.5
highDataCenterCap = round(dataCenterCap * (1+dataCenterCapScaleRatio))
lowDataCenterCap = round(dataCenterCap * (1-dataCenterCapScaleRatio))
module_sim.CQmod['CQsim'].fill_jobList()
while curHour < dataSize:# Init Integraded Simulator
    print('>>>>>>>>>>>>>>>>> current time (in hours):', curHour)
    renState = module_sim.get_renState(curHour)
    if renState == 'available':
        dataCenterCap = highDataCenterCap
    elif renState == 'outage':
        dataCenterCap = lowDataCenterCap
    else:
        print('Error: no renState')
        break
    workload, module_sim.workloadList = module_sim.CQmod['CQsim'].renaware_workload(module_sim.curTime, renState, dataCenterCap)
    module_sim.curTime += module_sim.timeInterval
    module_sim.REmod['REsim'].redux_sim(curHour, workload, renState)
    curHour += 1
# Out:
# ====================== ren-aware Sim ======================
# data size >>>>>>>>>>>>>>>>>>>> 7704
print('data center Capabiliy >>>>>>>>>>>>>>>>>>>>', dataCenterCap)
module_sim.CQmod['CQsim'].fill_jobList()
module_sim.REmod['REsim'].reset()
while curHour < dataSize:
    print('>>>>>>>>>>>>>>>>> current time (in hours):', curHour)
    renState = module_sim.get_renState(curHour)
    norWorkload, module_sim.norWorkloadList = module_sim.CQmod['CQsim'].normal_workload(module_sim.curTime, renState, dataCenterCap)
    module_sim.curTime += module_sim.timeInterval
    module_sim.REmod['REsim'].redux_sim(curHour, norWorkload, renState)
    curHour += 1
# Out:
# ====================== normal Sim ======================
# data size >>>>>>>>>>>>>>>>>>>> 2568
# data center Capabiliy >>>>>>>>>>>>>>>>>>>> 230
# job_num = >>>>>>>>>>>>>> 36000
# >>>>>>>>>>>>>>>>> current time (in hours): 0
# curTime>>>>>>>>>>>>>>> 3600.0
# normal workload>>>>>>>>>>>>>>>>>>> 6718730.96
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 6718730.96
# workload =  6718730.96 workloadBuffer= 0 renSupply= 209.0
# stableRenSupply= 209.0
# upsSupply= 500 upsStorage= 0
# gridSupply= 6717521.96
# reduxCost= 3686020.649452
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 1
# curTime>>>>>>>>>>>>>>> 7200.0
# normal workload>>>>>>>>>>>>>>>>>>> 6751975.68
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 6751975.68
# workload =  6751975.68 workloadBuffer= 0 renSupply= 241.0
# stableRenSupply= 225.615
# upsSupply= 0 upsStorage= 0
# gridSupply= 6751734.68
# reduxCost= 3442745.663332
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2
# curTime>>>>>>>>>>>>>>> 10800.0
# normal workload>>>>>>>>>>>>>>>>>>> 6710495.92
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 6710495.92
# workload =  6710495.92 workloadBuffer= 0 renSupply= 53.0
# upsSupply= 0 upsStorage= 0
# gridSupply= 6710442.92
# reduxCost= 3284769.75934
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 3
# curTime>>>>>>>>>>>>>>> 14400.0
# normal workload>>>>>>>>>>>>>>>>>>> 6666299.12
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 6666299.12
# workload =  6666299.12 workloadBuffer= 0 renSupply= 231.0
# stableRenSupply= 227.55
# upsSupply= 0 upsStorage= 0
# gridSupply= 6666068.12
# reduxCost= 3131753.452776
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 4
# curTime>>>>>>>>>>>>>>> 18000.0
# normal workload>>>>>>>>>>>>>>>>>>> 6624911.2
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 6624911.2
# workload =  6624911.2 workloadBuffer= 0 renSupply= 60.0
# upsSupply= 0 upsStorage= 0
# gridSupply= 6624851.2
# reduxCost= 3142838.40928
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 5
# curTime>>>>>>>>>>>>>>> 21600.0
# normal workload>>>>>>>>>>>>>>>>>>> 6625043.12
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 6625043.12
# workload =  6625043.12 workloadBuffer= 0 renSupply= 139.0
# stableRenSupply= 202.795
# upsSupply= 0 upsStorage= 0
# gridSupply= 6624904.12
# reduxCost= 3188596.772206
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 6
# curTime>>>>>>>>>>>>>>> 25200.0
# normal workload>>>>>>>>>>>>>>>>>>> 6610574.0
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 6610574.0
# workload =  6610574.0 workloadBuffer= 0 renSupply= 359.0
# stableRenSupply= 239.02
# upsSupply= 0 upsStorage= 0
# gridSupply= 6610215.0
# reduxCost= 3634335.957
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 7
# curTime>>>>>>>>>>>>>>> 28800.0
# normal workload>>>>>>>>>>>>>>>>>>> 6642902.88
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 61
# curTime>>>>>>>>>>>>>>> 223200.0
# normal workload>>>>>>>>>>>>>>>>>>> 2169160.96
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 2169160.96
# workload =  2169160.96 workloadBuffer= 0 renSupply= 668.0
# stableRenSupply= 313.454
# upsSupply= 500 upsStorage= 0
# gridSupply= 2167492.96
# reduxCost= 1370425.466078467
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 62
# curTime>>>>>>>>>>>>>>> 226800.0
# normal workload>>>>>>>>>>>>>>>>>>> 2042885.12
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 2042885.12
# workload =  2042885.12 workloadBuffer= 0 renSupply= 210.0
# stableRenSupply= 305.319
# upsSupply= 0 upsStorage= 0
# gridSupply= 2042675.12
# reduxCost= 1280598.045472
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 63
# curTime>>>>>>>>>>>>>>> 230400.0
# normal workload>>>>>>>>>>>>>>>>>>> 1866324.4
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 1866324.4
# workload =  1866324.4 workloadBuffer= 0 renSupply= 337.0
# upsSupply= -500 upsStorage= 500
# gridSupply= 1866487.4
# reduxCost= 1175195.01704
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 64
# curTime>>>>>>>>>>>>>>> 234000.0
# normal workload>>>>>>>>>>>>>>>>>>> 1742753.68
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 1742753.68
# workload =  1742753.68 workloadBuffer= 0 renSupply= 150.0
# stableRenSupply= 293.161
# upsSupply= 500 upsStorage= 0
# gridSupply= 1741603.68
# reduxCost= 1087199.357056
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 65
# curTime>>>>>>>>>>>>>>> 237600.0
# normal workload>>>>>>>>>>>>>>>>>>> 1547429.2
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 1547429.2
# workload =  1547429.2 workloadBuffer= 0 renSupply= 393.0
# stableRenSupply= 300.943
# upsSupply= 0 upsStorage= 0
# gridSupply= 1547036.2
# reduxCost= 956110.5815999999
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 66
# curTime>>>>>>>>>>>>>>> 241200.0
# normal workload>>>>>>>>>>>>>>>>>>> 1389129.44
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 1389129.44
# workload =  1389129.44 workloadBuffer= 0 renSupply= 103.0
# stableRenSupply= 285.574
# upsSupply= 0 upsStorage= 0
# gridSupply= 1389026.44
# reduxCost= 860123.5161957669
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 67
# curTime>>>>>>>>>>>>>>> 244800.0
# normal workload>>>>>>>>>>>>>>>>>>> 1244060.96
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 1244060.96
# workload =  1244060.96 workloadBuffer= 0 renSupply= 69.0
# upsSupply= 0 upsStorage= 0
# gridSupply= 1243991.96
# reduxCost= 765811.800576
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 68
# curTime>>>>>>>>>>>>>>> 248400.0
# normal workload>>>>>>>>>>>>>>>>>>> 1086587.12
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 1086587.12
# workload =  1086587.12 workloadBuffer= 0 renSupply= 203.0
# stableRenSupply= 279.185
# upsSupply= 0 upsStorage= 0
# gridSupply= 1086384.12
# reduxCost= 672405.009618
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 69
# curTime>>>>>>>>>>>>>>> 252000.0
# normal workload>>>>>>>>>>>>>>>>>>> 909696.96
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 909696.96
# workload =  909696.96 workloadBuffer= 0 renSupply= 58.0
# upsSupply= 0 upsStorage= 0
# gridSupply= 909638.96
# reduxCost= 547429.4261279999
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 70
# curTime>>>>>>>>>>>>>>> 255600.0
# normal workload>>>>>>>>>>>>>>>>>>> 719346.56
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 719346.56
# workload =  719346.56 workloadBuffer= 0 renSupply= 160.0
# stableRenSupply= 269.993
# upsSupply= 0 upsStorage= 0
# gridSupply= 719186.56
# reduxCost= 356253.60211800004
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 71
# curTime>>>>>>>>>>>>>>> 259200.0
# normal workload>>>>>>>>>>>>>>>>>>> 532240.72
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>>
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 76509.2
# workload =  76509.2 workloadBuffer= 0 renSupply= 50.0
# upsSupply= 0 upsStorage= 0
# gridSupply= 76459.2
# reduxCost= 52435.57343999999
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 117
# curTime>>>>>>>>>>>>>>> 424800.0
# normal workload>>>>>>>>>>>>>>>>>>> 73097.84
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 73097.84
# workload =  73097.84 workloadBuffer= 0 renSupply= 245.0
# upsSupply= 0 upsStorage= 0
# gridSupply= 72852.84
# reduxCost= 48476.603316
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 118
# curTime>>>>>>>>>>>>>>> 428400.0
# normal workload>>>>>>>>>>>>>>>>>>> 87434.48
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 87434.48
# workload =  87434.48 workloadBuffer= 0 renSupply= 98.0
# stableRenSupply= 315.359
# upsSupply= 0 upsStorage= 0
# gridSupply= 87336.48
# reduxCost= 49505.952474
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 119
# curTime>>>>>>>>>>>>>>> 432000.0
# normal workload>>>>>>>>>>>>>>>>>>> 140628.64
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 140628.64
# workload =  140628.64 workloadBuffer= 0 renSupply= 161.0
# upsSupply= -500 upsStorage= 500
# gridSupply= 140967.64
# reduxCost= 64977.941748000005
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 120
# curTime>>>>>>>>>>>>>>> 435600.0
# normal workload>>>>>>>>>>>>>>>>>>> 143675.44
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 143675.44
# workload =  143675.44 workloadBuffer= 0 renSupply= 120.0
# stableRenSupply= 300.79
# upsSupply= 500 upsStorage= 0
# gridSupply= 142555.44
# reduxCost= 55728.132688
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 121
# curTime>>>>>>>>>>>>>>> 439200.0
# normal workload>>>>>>>>>>>>>>>>>>> 146140.4
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 146140.4
# workload =  146140.4 workloadBuffer= 0 renSupply= 53.0
# upsSupply= 0 upsStorage= 0
# gridSupply= 146087.4
# reduxCost= 53709.678239999994
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 122
# curTime>>>>>>>>>>>>>>> 442800.0
# normal workload>>>>>>>>>>>>>>>>>>> 144816.8
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 144816.8
# workload =  144816.8 workloadBuffer= 0 renSupply= 195.0
# stableRenSupply= 292.904
# upsSupply= 0 upsStorage= 0
# gridSupply= 144621.8
# reduxCost= 49634.750819999994
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 123
# curTime>>>>>>>>>>>>>>> 446400.0
# normal workload>>>>>>>>>>>>>>>>>>> 162766.4
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 162766.4
# workload =  162766.4 workloadBuffer= 0 renSupply= 246.0
# stableRenSupply= 289.41
# upsSupply= 0 upsStorage= 0
# gridSupply= 162520.4
# reduxCost= 54780.28222
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 124
# curTime>>>>>>>>>>>>>>> 450000.0
# normal workload>>>>>>>>>>>>>>>>>>> 184335.92
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 184335.92
# workload =  184335.92 workloadBuffer= 0 renSupply= 134.0
# stableRenSupply= 277.836
# upsSupply= 0 upsStorage= 0
# gridSupply= 184201.92
# reduxCost= 63425.55607200001
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 125
# curTime>>>>>>>>>>>>>>> 453600.0
# normal workload>>>>>>>>>>>>>>>>>>> 168274.08
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 168274.08
# workload =  168274.08 workloadBuffer= 0 renSupply= 192.0
# upsSupply= -500 upsStorage= 500
# gridSupply= 168582.08
# reduxCost= 64598.71664
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 126
# curTime>>>>>>>>>>>>>>> 457200.0
# normal workload>>>>>>>>>>>>>>>>>>> 198939.2
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 198939.2
# workload =  198939.2 workloadBuffer= 0 renSupply= 572.0
# stableRenSupply= 299.734
# upsSupply= 500 upsStorage= 0
# gridSupply= 197367.2
# reduxCost= 86270.30671608391
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 127
# curTime>>>>>>>>>>>>>>> 460800.0
# normal workload>>>>>>>>>>>>>>>>>>> 196960.88
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>>
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2006
# curTime>>>>>>>>>>>>>>> 7225200.0
# normal workload>>>>>>>>>>>>>>>>>>> 765791.44
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 765791.44
# workload =  765791.44 workloadBuffer= 0 renSupply= 783.0
# upsSupply= 0 upsStorage= 0
# gridSupply= 765008.44
# reduxCost= 705954.8575879999
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2007
# curTime>>>>>>>>>>>>>>> 7228800.0
# normal workload>>>>>>>>>>>>>>>>>>> 774796.64
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 774796.64
# workload =  774796.64 workloadBuffer= 0 renSupply= 727.0
# upsSupply= 0 upsStorage= 0
# gridSupply= 774069.64
# reduxCost= 721976.816264
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2008
# curTime>>>>>>>>>>>>>>> 7232400.0
# normal workload>>>>>>>>>>>>>>>>>>> 833451.28
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 833451.28
# workload =  833451.28 workloadBuffer= 0 renSupply= 563.0
# stableRenSupply= 430.394
# upsSupply= 0 upsStorage= 0
# gridSupply= 832888.28
# reduxCost= 778975.7694560001
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2009
# curTime>>>>>>>>>>>>>>> 7236000.0
# normal workload>>>>>>>>>>>>>>>>>>> 994402.96
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 994402.96
# workload =  994402.96 workloadBuffer= 0 renSupply= 623.0
# upsSupply= 0 upsStorage= 0
# gridSupply= 993779.96
# reduxCost= 916435.451116
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2010
# curTime>>>>>>>>>>>>>>> 7239600.0
# normal workload>>>>>>>>>>>>>>>>>>> 1129943.52
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 1129943.52
# workload =  1129943.52 workloadBuffer= 0 renSupply= 297.0
# stableRenSupply= 420.513
# upsSupply= 0 upsStorage= 0
# gridSupply= 1129646.52
# reduxCost= 1013101.8891360001
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2011
# curTime>>>>>>>>>>>>>>> 7243200.0
# normal workload>>>>>>>>>>>>>>>>>>> 1292139.92
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 1292139.92
# workload =  1292139.92 workloadBuffer= 0 renSupply= 249.0
# stableRenSupply= 407.808
# upsSupply= 0 upsStorage= 0
# gridSupply= 1291890.92
# reduxCost= 1099178.144736
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2012
# curTime>>>>>>>>>>>>>>> 7246800.0
# normal workload>>>>>>>>>>>>>>>>>>> 1494480.96
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 1494480.96
# workload =  1494480.96 workloadBuffer= 0 renSupply= 46.0
# upsSupply= 0 upsStorage= 0
# gridSupply= 1494434.96
# reduxCost= 1083173.3590079998
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2013
# curTime>>>>>>>>>>>>>>> 7250400.0
# normal workload>>>>>>>>>>>>>>>>>>> 1652887.28
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 1652887.28
# workload =  1652887.28 workloadBuffer= 0 renSupply= 20.0
# upsSupply= 0 upsStorage= 0
# gridSupply= 1652867.28
# reduxCost= 1170728.894424
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2014
# curTime>>>>>>>>>>>>>>> 7254000.0
# normal workload>>>>>>>>>>>>>>>>>>> 1815567.28
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 1815567.28
# workload =  1815567.28 workloadBuffer= 0 renSupply= 133.0
# stableRenSupply= 387.452
# upsSupply= 0 upsStorage= 0
# gridSupply= 1815434.28
# reduxCost= 1066807.300728
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2015
# curTime>>>>>>>>>>>>>>> 7257600.0
# normal workload>>>>>>>>>>>>>>>>>>> 1979695.84
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 1979695.84
# workload =  1979695.84 workloadBuffer= 0 renSupply= 180.0
# stableRenSupply= 372.085
# upsSupply= 0 upsStorage= 0
# gridSupply= 1979515.84
# reduxCost= 1079287.848718
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2016
# curTime>>>>>>>>>>>>>>> 7261200.0
# normal workload>>>>>>>>>>>>>>>>>>> 2174129.28
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 2174129.28
# workload =  2174129.28 workloadBuffer= 0 renSupply= 204.0
# stableRenSupply= 359.635
# upsSupply= 0 upsStorage= 0
# gridSupply= 2173925.28
# reduxCost= 1154625.661458
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2027
# curTime>>>>>>>>>>>>>>> 7300800.0
# normal workload>>>>>>>>>>>>>>>>>>> 4142414.56
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 4142414.56
# workload =  4142414.56 workloadBuffer= 0 renSupply= 545.0
# upsSupply= 0 upsStorage= 0
# gridSupply= 4141869.56
# reduxCost= 2967702.66974
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2028
# curTime>>>>>>>>>>>>>>> 7304400.0
# normal workload>>>>>>>>>>>>>>>>>>> 4281016.32
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 4281016.32
# workload =  4281016.32 workloadBuffer= 0 renSupply= 411.0
# stableRenSupply= 386.991
# upsSupply= 0 upsStorage= 0
# gridSupply= 4280605.32
# reduxCost= 3767827.892664
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2029
# curTime>>>>>>>>>>>>>>> 7308000.0
# normal workload>>>>>>>>>>>>>>>>>>> 4382656.96
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 4382656.96
# workload =  4382656.96 workloadBuffer= 0 renSupply= 265.0
# stableRenSupply= 377.954
# upsSupply= 0 upsStorage= 0
# gridSupply= 4382391.96
# reduxCost= 3883702.244952
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2030
# curTime>>>>>>>>>>>>>>> 7311600.0
# normal workload>>>>>>>>>>>>>>>>>>> 4645620.0
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 4645620.0
# workload =  4645620.0 workloadBuffer= 0 renSupply= 243.0
# stableRenSupply= 367.958
# upsSupply= 0 upsStorage= 0
# gridSupply= 4645377.0
# reduxCost= 4199912.5557
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2031
# curTime>>>>>>>>>>>>>>> 7315200.0
# normal workload>>>>>>>>>>>>>>>>>>> 4833108.0
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 4833108.0
# workload =  4833108.0 workloadBuffer= 0 renSupply= 613.0
# stableRenSupply= 386.109
# upsSupply= 0 upsStorage= 0
# gridSupply= 4832495.0
# reduxCost= 4468182.747
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2032
# curTime>>>>>>>>>>>>>>> 7318800.0
# normal workload>>>>>>>>>>>>>>>>>>> 5001706.4
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 5001706.4
# workload =  5001706.4 workloadBuffer= 0 renSupply= 466.0
# upsSupply= 0 upsStorage= 0
# gridSupply= 5001240.4
# reduxCost= 4636700.2548400005
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2033
# curTime>>>>>>>>>>>>>>> 7322400.0
# normal workload>>>>>>>>>>>>>>>>>>> 5151868.16
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 5151868.16
# workload =  5151868.16 workloadBuffer= 0 renSupply= 499.0
# upsSupply= 0 upsStorage= 0
# gridSupply= 5151369.16
# reduxCost= 4716653.032896
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2034
# curTime>>>>>>>>>>>>>>> 7326000.0
# normal workload>>>>>>>>>>>>>>>>>>> 5294156.56
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 5294156.56
# workload =  5294156.56 workloadBuffer= 0 renSupply= 349.0
# stableRenSupply= 383.36
# upsSupply= 0 upsStorage= 0
# gridSupply= 5293807.56
# reduxCost= 4568071.3935239995
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2035
# curTime>>>>>>>>>>>>>>> 7329600.0
# normal workload>>>>>>>>>>>>>>>>>>> 5450323.36
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 5450323.36
# workload =  5450323.36 workloadBuffer= 0 renSupply= 222.0
# stableRenSupply= 371.408
# upsSupply= 0 upsStorage= 0
# gridSupply= 5450101.36
# reduxCost= 4547597.874784
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2036
# curTime>>>>>>>>>>>>>>> 7333200.0
# normal workload>>>>>>>>>>>>>>>>>>> 5602220.08
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 5602220.08
# workload =  5602220.08 workloadBuffer= 0 renSupply= 216.0
# stableRenSupply= 359.896
# upsSupply= 0 upsStorage= 0
# gridSupply= 5602004.08
# reduxCost= 4096217.7832959997
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2037
# curTime>>>>>>>>>>>>>>> 7336800.0
# normal workload>>>>>>>>>>>>>>>>>>> 5735706.88
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 5735706.88
# workload =  5735706.88 workloadBuffer= 0 renSupply= 245.0
# upsSupply= -500 upsStorage= 500
# gridSupply= 5735961.88
# reduxCost= 3916561.5216639997
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2038
# curTime>>>>>>>>>>>>>>> 7340400.0
# normal workload>>>>>>>>>>>>>>>>>>> 5878723.12
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 5878723.12
# workload =  5878723.12 workloadBuffer= 0 renSupply= 37.0
# upsSupply= 0 upsStorage= 500
# gridSupply= 5878686.12
# reduxCost= 3374959.251492
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2039
# curTime>>>>>>>>>>>>>>> 7344000.0
# normal workload>>>>>>>>>>>>>>>>>>> 6066077.2
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 6066077.2
# workload =  6066077.2 workloadBuffer= 0 renSupply= 53.0
# upsSupply= 0 upsStorage= 500
# gridSupply= 6066024.2
# reduxCost= 3298105.30754
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2040
# curTime>>>>>>>>>>>>>>> 7347600.0
# normal workload>>>>>>>>>>>>>>>>>>> 6168626.48
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 6168626.48
# workload =  6168626.48 workloadBuffer= 0 renSupply= 37.0
# upsSupply= 0 upsStorage= 500
# gridSupply= 6168589.48
# reduxCost= 3585189.755776
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2041
# curTime>>>>>>>>>>>>>>> 7351200.0
# normal workload>>>>>>>>>>>>>>>>>>> 6331320.56
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 6331320.56
# workload =  6331320.56 workloadBuffer= 0 renSupply= 159.0
# stableRenSupply= 345.015
# upsSupply= 500 upsStorage= 0
# gridSupply= 6330161.56
# reduxCost= 3332938.9113399996
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2042
# curTime>>>>>>>>>>>>>>> 7354800.0
# normal workload>>>>>>>>>>>>>>>>>>> 6514672.32
# Start REDUX
# workload in redux>>>>>>>>>>>>>>>>> 6514672.32
# workload =  6514672.32 workloadBuffer= 0 renSupply= 184.0
# stableRenSupply= 333.088
# upsSupply= 0 upsStorage= 0
# gridSupply= 6514488.32
# reduxCost= 3250779.6348800003
#
#
# >>>>>>>>>>>>>>>>> current time (in hours): 2043
# curTime>>>>>>>>>>>>>>> 7358400.0
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-13-a5f185cd7798> in <module>
#      10     print('>>>>>>>>>>>>>>>>> current time (in hours):', curHour)
#      11     renState = module_sim.get_renState(curHour)
# ---> 12     norWorkload, module_sim.norWorkloadList = module_sim.CQmod['CQsim'].normal_workload(module_sim.curTime, renState, dataCenterCap)
#      13     module_sim.curTime += module_sim.timeInterval
#      14     module_sim.REmod['REsim'].redux_sim(curHour, norWorkload, renState)
#
# C:/Users/xzp0007/Dropbox/Workspace/CQSim-REDUX\srcCQSim\ReCqsim_sim.py in normal_workload(self, curTime, renState, dataCenterCap)
#     157         print('curTime>>>>>>>>>>>>>>>',curTime)
#     158         # fill the waitQueue with all jobs
# --> 159         self.fill_waitQueue(curTime)
#     160         self.fill_window(dataCenterCap)
#     161         self.windowSize = 0
#
# C:/Users/xzp0007/Dropbox/Workspace/CQSim-REDUX\srcCQSim\ReCqsim_sim.py in fill_waitQueue(self, curTime)
#     181                 j = i
#     182                 break
# --> 183         self.newJob = j
#     184         while j > 0:
#     185             self.jobList.remove(self.jobList[0])
#
# UnboundLocalError: local variable 'j' referenced before assignment

# %%
nor_wl = module_sim.norWorkloadList
, 268273.90625, 199903.02067600001, 180837.48760000002, 162566.83376, 192194.59820799998, 168795.33954, 175557.175646, 193178.58889, 237282.1086892101, 294036.123384, 327717.52766, 369494.7227739283, 398405.02636, 372069.24752, 428823.70672799996, 458983.2076080001, 433771.826704, 436644.33644000004, 445425.613808, 427920.2024280001, 383161.097916, 389318.30140000005, 320377.940972, 292751.82879999996, 234372.364752, 214124.40256, 166513.798368, 157155.945784, 143645.34768, 153172.47984, 158643.98736, 176891.71008000002, 225855.84611262297, 274719.18943209754, 303956.000752, 345817.57000799995, 405176.51265600004, 440797.000804, 439577.41429999995, 453757.529784, 443504.113412, 439152.93940000003, 425228.94496, 417329.71869999997, 392873.041176, 383970.3835720001, 313283.97188400006, 270524.202982, 238493.73624000003, 195816.07897200002, 202666.264576, 186096.792706, 187716.58144399998, 195365.476042, 200509.17530400003, 203752.408792, 200492.59980400003, 217747.99738, 247985.8524510476, 272849.5569063158, 293056.8608546667, 315219.530528, 308361.50112, 323266.43174399994, 320021.55410000007, 311438.7882800001, 296347.259712, 305717.67422734376, 294944.014986 ...
# []

# %% [markdown]
# # Plots

# %%
diff = []
for i in range(len(nor_wl)):
    diff.append(nor_wl[i] - ren_wl[i])

# %%
print(ren_wl[0], nor_wl[0])
# Out:
# 3080.48 6718730.96

# %%
ren_wl = [x/1000 for x in ren_wl]
nor_wl = [x/1000 for x in nor_wl]

# %%
plt.close()
plt.plot(ren_wl, label='ren-aware')
plt.plot(nor_wl, label='normal')
plt.legend(loc='best')
plt.ylabel('1000 kW/h')
plt.xlabel('hourly time slot')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
plt.close()
plt.plot(diff)
plt.title('Difference between normal and ren-aware workload')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
diff2 = copy.deepcopy(diff)
# diff2.sort()
for i in range(5):
    print(diff2[i])
# Out:
# 6715650.4799999995
# 6750717.68
# 6708767.92
# 6664421.68
# 6623631.36

# %%
d = np.array(diff2)
d.argsort()[-5:][::-1]
# Out:
# array([1, 0, 2, 3, 8], dtype=int64)

# %%
print(diff2[1501],diff2[2370],diff2[2274])
print(ren_wl[1501],ren_wl[2370],ren_wl[2274])
print(nor_wl[1501],nor_wl[2370],nor_wl[2274])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-26-299d3d3efdec> in <module>
# ----> 1 print(diff2[1501],diff2[2370],diff2[2274])
#       2 print(ren_wl[1501],ren_wl[2370],ren_wl[2274])
#       3 print(nor_wl[1501],nor_wl[2370],nor_wl[2274])
#
# IndexError: list index out of range

# %%
d.argsort()[:5][::-1]
# Out:
# array([1559, 1557, 1564, 1540, 1535], dtype=int64)

# %%
print(diff2[2191],diff2[1494],diff2[1757])
print(ren_wl[2191],ren_wl[1494],ren_wl[1757])
print(nor_wl[2191],nor_wl[1494],nor_wl[1757])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-28-c05d706fe03a> in <module>
# ----> 1 print(diff2[2191],diff2[1494],diff2[1757])
#       2 print(ren_wl[2191],ren_wl[1494],ren_wl[1757])
#       3 print(nor_wl[2191],nor_wl[1494],nor_wl[1757])
#
# IndexError: list index out of range

# %%
plt.close()
plt.plot(accu_ren_wl, label='ren-aware')
plt.plot(accu_nor_wl, label='normal')
plt.legend(loc='best')
plt.title('accumulated normal and ren-aware workload')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
diff_accu = []
for i in range(len(accu_nor_wl)):
    diff_accu.append(accu_nor_wl[i] - accu_ren_wl[i])

# %%
plt.close()
plt.plot(diff_accu)
plt.title('Difference between accumulated normal and ren-aware workload')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
accu_ren_reduxCost = [x/1000000 for x in accu_ren_reduxCost]
accu_nor_reduxCost = [x/1000000 for x in accu_nor_reduxCost]

# %%
plt.close()
plt.plot(accu_ren_reduxCost, label='accumulated ren-aware redux cost')
plt.plot(accu_nor_reduxCost, label='accumulated normal redux cost')
plt.ylabel('million dollers')
plt.xlabel('hourly time slot')
plt.legend(loc='best')
plt.title('GAIA')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
accu_ren_reduxCost_list = []
accu_nor_reduxCost_list = []
for i in [1000, 2000, -1]:
    accu_ren_reduxCost_list.append(round(accu_ren_reduxCost[i],2))
    accu_nor_reduxCost_list.append(round(accu_nor_reduxCost[i],2))
print(accu_ren_reduxCost_list)
print(accu_nor_reduxCost_list)
# Out:
# [257.13, 951.75, 1041.33]
# [505.72, 1230.52, 1323.15]

# %%
atlas_ren = [10.73, 22.43, 39.87]
atlas_nor = [12.34, 23.31, 40.95]

# %%
sp2_ren = [13.03, 30.63, 36.88]
sp2_nor = [13.6, 32.92, 39.54]

# %%
blue_ren = [20.05, 35.68, 40.65]
blue_nor = [20.91, 37.4, 42.56]

# %%
ross_ren = [95.39, 201.36, 258.84]
ross_nor = [100.17, 205.47, 263.46]

# %%
gaia_ren = [257.13, 951.75, 1041.33]
gaia_nor = [505.72, 1230.52, 1323.15]

# %%
plt.close()
plt.figure()


labels = ['sp2', 'blue',  'ross', 'gaia']
x = np.arange(len(labels))
width = 0.2
ren1000 = [13.03, 20.05,95.39,157.13]
nor1000 = [13.6, 20.91,100.17,205.72]
ren2000 = [30.63,35.68,201.36,351.75]
nor2000 = [32.92,37.4,205.47,530.52]
renEnd = [36.88,40.65,258.84,541.33]
norEnd = [39.54,42.56,263.46,723.15]

# fig, ax = plt.subplots()
plt.subplot(131)
plt.title('t=1000', loc='left', fontdict={'fontsize':10})
# fig, ren1000x = plt.subplots()
plt.bar(x-width/2,ren1000,width,label='ren',tick_label = ['sp2', 'blue',  'ross', 'gaia'])
plt.bar(x+width/2,nor1000,width,label='nor')
# plt.bar(['sp2', 'blue',  'ross', 'gaia'],[13.03, 20.05,95.39,257.13],width=0.2)
# plt.bar(['sp2', 'blue',  'ross', 'gaia'],[16.03, 26.05,106.39,277.13],width=0.2)
plt.ylabel('million dollers')
plt.legend(loc='best')

plt.subplot(132)
plt.title('t=2000', loc='left', fontdict={'fontsize':10})
plt.bar(x-width/2,ren2000,width,label='ren',tick_label = ['sp2', 'blue',  'ross', 'gaia'])
plt.bar(x+width/2,nor2000,width,label='nor')

plt.subplot(133)
plt.title('end', loc='left', fontdict={'fontsize':10})
plt.bar(x-width/2,renEnd,width,label='ren',tick_label = ['sp2', 'blue',  'ross', 'gaia'])
plt.bar(x+width/2,norEnd,width,label='nor')


# plt.suptitle('Title')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
