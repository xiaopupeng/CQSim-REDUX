# %%
import sys
path_cqsim='/Users/xiaopupeng/dropbox/workspace/cqsim-redux/'
path_data=path_cqsim+'data/'
path_src=path_cqsim+'src/'
sys.path.append(path_src)

# %%
import os
from datetime import datetime
import time
import re
import cqsim

# %%
inputPara = cqsim.initPara()
inputPara['alg_sign']=cqsim.alg_sign_check(inputPara['alg_sign'],len(inputPara['alg']))

# %%
cqsim.cqsim_main(inputPara)
# Out:
# ....................
# job_trace: SDSC-SP2-1998-4.2-cln.swf
# node_struc: SDSC-SP2-1998-4.2-cln.swf
# output: output_SDSC-SP2-1998-4.2-cln
# job_save: jobSave_SDSC-SP2-1998-4.2-cln
# node_save: nodeSave_SDSC-SP2-1998-4.2-cln
# cluster_fraction: 1.0
# start: 0.0
# start_date: None
# anchor: 0
# read_num: 8000
# alg: ['w', '+', '2']
# alg_sign: [1, 0, 1]
# backfill: 2
# bf_para: None
# win: 5
# win_para: ['5', '0', '0']
# ad_bf: 0
# ad_bf_para: ad_bf_para.set
# ad_win: 0
# ad_win_para: None
# ad_alg: 0
# ad_alg_para: None
# monitor: 500
# config: config.set
# pre_name: CQSIM_
# path_in: /Users/xiaopupeng/dropbox/workspace/cqsim-redux/data/InputFiles/
# path_out: /Users/xiaopupeng/dropbox/workspace/cqsim-redux/data/Results/
# path_fmt: /Users/xiaopupeng/dropbox/workspace/cqsim-redux/data/Fmt/
# ext_jr: .rst
# ext_si: .ult
# ext_ai: .adp
# resource_job: 0
# resource_node: 0
# ....................
# .................... Job Filter
# .................... Node Filter
# ...
